# %%
# %sql
insert into bankaml.bronze.watermark_control
values
("silver", "accounts", "silver", "_ingestion_ts", null, "Y", null),
("silver", "branches", "silver", "_ingestion_ts", null, "Y", null),
("silver", "customers", "silver", "_ingestion_ts", null, "Y", null),
("silver", "transactions", "silver", "_ingestion_ts", null, "Y", null)
