# %%
# %sql
CREATE TABLE IF NOT EXISTS bankaml.silver.fx_rates (
    currency STRING,
    rate_to_usd DOUBLE,
    effective_date DATE
)

# %%
# %sql
INSERT INTO bankaml.silver.fx_rates VALUES
    ('USD', 1.00,     DATE('2026-01-01')),
    ('INR', 0.012,    DATE('2026-01-01')),
    ('GBP', 1.27,     DATE('2026-01-01')),
    ('CNY', 0.14,     DATE('2026-01-01')),
    ('AED', 0.27,     DATE('2026-01-01')),
    ('SGD', 0.74,     DATE('2026-01-01')),
    ('EUR', 1.09,     DATE('2026-01-01')),
    ('CAD', 0.73,     DATE('2026-01-01')),
    ('NGN', 0.00062,  DATE('2026-01-01')),
    ('RUB', 0.011,    DATE('2026-01-01')),
    ('AUD', 0.65,     DATE('2026-01-01'))
