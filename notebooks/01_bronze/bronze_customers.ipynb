# %%
# %run "/Workspace/Users/jeevan.azureacc3@gmail.com/bankaml-de-project/notebooks/01_bronze/bronze_util"

# %%
from pyspark.sql.functions import *
from delta.tables import *
from pyspark.sql.types import *

# %%
dbutils.fs.mkdirs("abfss://bronze@stbankamldev01.dfs.core.windows.net/_checkpoints/customers/")
dbutils.fs.mkdirs("abfss://bronze@stbankamldev01.dfs.core.windows.net/_schemas/customers/")

# %%
landing_path = "abfss://landing@stbankamldev01.dfs.core.windows.net/core-banking/ingestion_date=*/customers/"
checkpoint_path = "abfss://bronze@stbankamldev01.dfs.core.windows.net/_checkpoints/customers/"
schema_path = "abfss://bronze@stbankamldev01.dfs.core.windows.net/_schemas/customers/"
target_table = "bankaml.bronze.customers"

customers_schema = StructType([
    StructField("customer_id", StringType(), True),
    StructField("name", StringType(), True),
    StructField("dob", StringType(), True),
    StructField("ssn_hash", StringType(), True),
    StructField("risk_rating", StringType(), True),
    StructField("kyc_status", StringType(), True),
    StructField("country", StringType(), True),
    StructField("created_at", StringType(), True),
    StructField("created_by", StringType(), True),
])

read_source_and_load_into_bronze_as_delta_table(customers_schema, schema_path, landing_path, checkpoint_path, target_table)
