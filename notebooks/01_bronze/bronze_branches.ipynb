# %%
# %run "/Workspace/Users/jeevan.azureacc3@gmail.com/bankaml-de-project/notebooks/01_bronze/bronze_util"

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
from delta.tables import *

# %%
dbutils.fs.mkdirs("abfss://bronze@stbankamldev01.dfs.core.windows.net/_checkpoints/branches/")
dbutils.fs.mkdirs("abfss://bronze@stbankamldev01.dfs.core.windows.net/_schemas/branches/")

# %%
source_path = "abfss://landing@stbankamldev01.dfs.core.windows.net/core-banking/ingestion_date=*/branches"
schema_path = "abfss://bronze@stbankamldev01.dfs.core.windows.net/_schemas/branches/"
checkpoints_path= "abfss://bronze@stbankamldev01.dfs.core.windows.net/_checkpoints/branches/"
target_table = "bankaml.bronze.branches"

branches_schema = StructType(
    [
        StructField("branch_id", StringType()),
        StructField("branch_name", StringType()),
        StructField("city", StringType()),
        StructField("country", StringType()),
        StructField("region_code", StringType()),
        StructField("created_at", StringType()),
        StructField("created_by", StringType())
    ]
)

read_source_and_load_into_bronze_as_delta_table(branches_schema, schema_path, source_path, checkpoints_path, target_table)
