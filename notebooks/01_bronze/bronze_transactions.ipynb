# %%
# %run "/Workspace/Users/jeevan.azureacc3@gmail.com/bankaml-de-project/notebooks/01_bronze/bronze_util"

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
from delta.tables import *

# %%
dbutils.fs.mkdirs("abfss://bronze@stbankamldev01.dfs.core.windows.net/_checkpoints/transactions/")
dbutils.fs.mkdirs("abfss://bronze@stbankamldev01.dfs.core.windows.net/_schemas/transactions/")

# %%
source_path = "abfss://landing@stbankamldev01.dfs.core.windows.net/core-banking/ingestion_date=*/transactions"
schema_path = "abfss://bronze@stbankamldev01.dfs.core.windows.net/_schemas/transactions/"
checkpoints_path= "abfss://bronze@stbankamldev01.dfs.core.windows.net/_checkpoints/transactions/"
target_table = "bankaml.bronze.transactions"

transactions_schema = StructType(
    [
        StructField("txn_id", StringType()),
        StructField("account_id", StringType()),
        StructField("txn_ts", StringType()),
        StructField("txn_type", StringType()),
        StructField("amount", StringType()),
        StructField("currency", StringType()),
        StructField("counterparty_acct", StringType()),
        StructField("channel", StringType()),
        StructField("created_at", StringType()),
        StructField("source_system", StringType())
    ]
)

read_source_and_load_into_bronze_as_delta_table(transactions_schema, schema_path, source_path, checkpoints_path, target_table)
